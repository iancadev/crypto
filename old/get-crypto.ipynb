# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import os
import requests
import zipfile


for ticker in ["BTCUSDC", "SANDUSDC", "XRPUSDC", "ETHUSDC"]:
    url = f"https://data.binance.vision/?prefix=data/spot/monthly/klines/{ticker}/30m/"
    output_csv = f"tmp/{ticker}.csv"
    target_csv = f"assets/{ticker}.csv"

    # Set up Selenium WebDriver
    options = Options()
    options.add_argument("--headless")  # Run in headless mode
    # service = Service('path/to/msedgedriver')  # Replace with the path to your Edge WebDriver
    driver = webdriver.Edge(options=options)

    try:
        # Launch the URL
        driver.get(url)
        time.sleep(5)  # Wait for 5 seconds

        # Find all links ending with ".zip"
        links = driver.find_elements(By.XPATH, "//a[substring(@href, string-length(@href) - 3) = '.zip']")
        zip_links = [link.get_attribute('href') for link in links]

        for link in zip_links:
            print(link)

        # Create the local folder if it doesn't exist
        os.makedirs('tmp', exist_ok=True)

        with open(output_csv, 'w') as file:
            file.write("Open time,Open,High,Low,Close,Volume,Close time,Quote asset volume,Number of trades,Taker buy base asset volume,Taker buy quote asset volume,Ignore\n")

        # Download and save each linked resource
        for i, link in enumerate(zip_links):
            print(f"{i+1}/{len(zip_links)}")

            file_name = os.path.join('tmp', os.path.basename(link))
            response = requests.get(link)
            with open(file_name, 'wb') as file:
                file.write(response.content)

            time.sleep(1)

            if zipfile.is_zipfile(file_name):
                with zipfile.ZipFile(file_name, 'r') as zip_ref:
                    zip_ref.extractall('tmp')

            os.remove(file_name)

            time.sleep(1)

            # Get the name of the extracted CSV file
            extracted_files = zip_ref.namelist()
            if len(extracted_files) == 1:
                extracted_csv = os.path.join('tmp', extracted_files[0])
                
                # Append the content of the extracted CSV to master.csv
                with open(extracted_csv, 'r') as source_file:
                    with open(output_csv, 'a') as master_file:
                        master_file.write(source_file.read())
                
                # Delete the original extracted CSV file
                os.remove(extracted_csv)
            time.sleep(1)
        
        # Move the consolidated CSV to the target location
        os.makedirs(os.path.dirname(target_csv), exist_ok=True)
        os.replace(output_csv, target_csv)
    finally:
        driver.quit()
# Out:
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2025-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2025-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-12.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-11.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-10.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2024-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-12.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-11.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-10.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2023-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2022-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-12.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-11.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-10.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2021-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-12.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-11.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-10.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2020-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-12.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-11.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-10.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-09.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-08.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-07.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-06.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-05.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-04.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-03.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-02.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2019-01.zip
# https://data.binance.vision/data/spot/monthly/klines/BTCUSDC/30m/BTCUSDC-30m-2018-12.zip
# 1/70
# 2/70
# 3/70
# 4/70
# 5/70
# 6/70
# 7/70
# 8/70
# 9/70
# 10/70
# 11/70
# 12/70
# 13/70
# 14/70
# 15/70
# 16/70
# 17/70
# 18/70
# 19/70
# 20/70
# 21/70
# 22/70
# 23/70
# 24/70
# 25/70
# 26/70
# 27/70
# 28/70
# 29/70
# 30/70
# 31/70
# 32/70
# 33/70
# 34/70
# 35/70
# 36/70
# 37/70
# 38/70
# 39/70
# 40/70
# 41/70
# 42/70
# 43/70
# 44/70
# 45/70
# 46/70
# 47/70
# 48/70
# 49/70
# 50/70
# 51/70
# 52/70
# 53/70
# 54/70
# 55/70
