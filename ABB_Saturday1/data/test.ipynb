# %%
import sys, importlib
sys.path.append('..')
import data

# %%
importlib.reload(data)#
# Out:
# <module 'data' from 'c:\\Users\\ic2594\\crypto\\ABB_Saturday1\\data\\..\\data\\__init__.py'>

# %%
data.plot_available_times([
    "BTCUSDC",
    "ETHUSDC",
    "ETHBTC",
    "ETHUSDT"
])

# %%
data.plot_available_times([
    "BTCUSDC",
    "BTCTUSD",
    "BTCUSDT",
    "BTCUST",
    "BTCEUR",
])

# %%
data.plot_available_times([
    "BTCUSDT",
    "ETHUSDT",
    "XLMUSDT",
    "XRPUSDT",
    "BNBUSDT",
    "SOLUSDT",
    "DOGEUSDT",
    "ADAUSDT",
    "TRXUSDT",
    "LINKUSDT",
    "BCHUSDT",
    "LTCUSDT",
])

# %%
data.available_times.keys()
# Out:
# dict_keys(['BTCUSDC', 'ETHUSDC', 'ETHBTC', 'ETHUSDT'])
