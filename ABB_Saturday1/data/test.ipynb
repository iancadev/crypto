# %%
import sys, importlib
sys.path.append('..')
import data

# %%
importlib.reload(data)#
# Out:
# <module 'data' from 'c:\\Users\\ic2594\\crypto\\ABB_Saturday1\\data\\..\\data\\__init__.py'>

# %%
data.plot_available_times([
    "BTCUSDC",
    "ETHUSDC",
    "ETHBTC",
])

# %%
data.plot_available_times([
    "BTCUSDC",
    "BTCTUSD",
    "BTCUSDT",
    "BTCUST",
    "BTCEUR",
])
