# %%
import sys, importlib
sys.path.append('..')
import data
importlib.reload(data)
import data

# %%
df = data.load_asset('XLMUSDC')
df.head()
# Out:
#                        Open    High     Low   Close   Volume  \
# Open time
# 2025-02-01 00:00:00  0.4140  0.4148  0.4132  0.4135  38848.0
# 2025-02-01 00:30:00  0.4134  0.4157  0.4134  0.4157  35403.0
# 2025-02-01 01:00:00  0.4158  0.4163  0.4154  0.4156  24289.0
# 2025-02-01 01:30:00  0.4156  0.4171  0.4150  0.4160  11495.0
# 2025-02-01 02:00:00  0.4154  0.4191  0.4154  0.4178   5771.0
#
#                      Quote asset volume  Number of trades  \
# Open time
# 2025-02-01 00:00:00          16096.7628                65
# 2025-02-01 00:30:00          14702.6231                46
# 2025-02-01 01:00:00          10099.4756                41
# 2025-02-01 01:30:00           4786.9575                31
# 2025-02-01 02:00:00           2414.8026                21
#
#                      Taker buy base asset volume  Taker buy quote asset volume
# Open time
# 2025-02-01 00:00:00                      27407.0                    11362.2104
# ...

# %%
data.add_fear_and_greed(df.iloc[3000:3200,:]).tail()
# Out:
# c:\Users\ic2594\crypto\layouts\sentiment_forecast_rl\data\..\data\__init__.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['plain-date', :] = df.index.map(lambda x: x.replace(hour=0, minute=0, second=0, microsecond=0))
# c:\Users\ic2594\crypto\layouts\sentiment_forecast_rl\data\..\data\__init__.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['F&G value'] = df['plain-date'].map(lambda x: f_n_g_csv['value'].loc[x] if x.date() in f_n_g_csv.index.date else None)
# ...
