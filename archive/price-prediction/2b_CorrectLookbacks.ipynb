# %% [markdown]
# In this notebook:
# - The environment and the hyperparameters are modified to improve performance
#   - The environment will be designed for <b>MlpLstmPolicy</b>
#     - Lookback periods will provide a returns HISTORY, but for the rest of the indicators only the current period
#     - The reward function will use a geometric-decay based on previous actions of the agent
#     - Portfolio weights will be normalized to sum to 1, with all zero-weights being penalized by a set value.
#   - The randomly-selected episodes run for longer (100 time-steps)
# - Again, the model is trained and tested for multiple assets and compared to the equal-weights portfolio

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
import matplotlib.pyplot as plt

import importlib
import library
import callbacks
importlib.reload(library)
importlib.reload(callbacks)
import library
import callbacks


TICKERS = []
def getData():
    global TICKERS

    df = library.contiguousZones(*['2/SOLUSDC.csv', '2/DOGEUSDC.csv', '2/BTCUSDC.csv'])
    TICKERS = set(ticker[0] for ticker in df.columns)

    return df

getData().head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      11 import importlib
#      12 import library
# ---> 13 import callbacks
#      14 importlib.reload(library)
#      15 importlib.reload(callbacks)
#
# ModuleNotFoundError: No module named 'callbacks'

# %%
# BLANK FOR NOW
# (optional) put stuff in
def add_financial_indicators(df):
    for ticker in TICKERS:
        df[(ticker, "Returns")] = df[(ticker, "Open")].pct_change().shift(-1)
    return df

add_financial_indicators(getData()).head()
# Out:
#                     SOLUSDC                                    \
#                        Open    High     Low   Close    Volume
# Open time
# 2024-08-01 00:00:00  171.58  172.89  171.26  171.42  2366.117
# 2024-08-01 00:30:00  171.32  172.56  171.11  171.97  1889.412
# 2024-08-01 01:00:00  171.89  172.32  171.07  171.81  1214.505
# 2024-08-01 01:30:00  171.80  171.80  169.97  171.10  3871.560
# 2024-08-01 02:00:00  171.18  171.54  169.44  169.56  4710.776
#
#                                                          \
#                     Quote asset volume Number of trades
# Open time
# 2024-08-01 00:00:00       407105.82230            752.0
# 2024-08-01 00:30:00       324621.59381            628.0
# 2024-08-01 01:00:00       208544.08849            373.0
# 2024-08-01 01:30:00       661030.69686            873.0
# 2024-08-01 02:00:00       801793.08710           1476.0
#
#                                                                               \
#                     Taker buy base asset volume Taker buy quote asset volume
# Open time
# 2024-08-01 00:00:00                     741.076                 127524.08388
# 2024-08-01 00:30:00                     910.237                 156410.54570
# 2024-08-01 01:00:00                     775.572                 133211.30871
# 2024-08-01 01:30:00                    1573.397                 269039.05509
# 2024-08-01 02:00:00                    2556.853                 435360.79159
#
#                     DOGEUSDC  ...   BTCUSDC                      \
#                         Open  ...       Low     Close    Volume
# Open time                     ...
# 2024-08-01 00:00:00  0.12190  ...  64323.20  64548.00  67.26043
# 2024-08-01 00:30:00  0.12229  ...  64340.01  64626.00  46.49807
# 2024-08-01 01:00:00  0.12283  ...  64386.00  64532.00  36.50007
# 2024-08-01 01:30:00  0.12248  ...  64105.00  64182.01  68.35677
# 2024-08-01 02:00:00  0.12242  ...  63877.57  63988.01  96.48837
#
#                                                          \
#                     Quote asset volume Number of trades
# Open time
# 2024-08-01 00:00:00       4.343514e+06             6344
# 2024-08-01 00:30:00       3.003529e+06             6577
# 2024-08-01 01:00:00       2.356451e+06             4948
# 2024-08-01 01:30:00       4.392649e+06             9438
# 2024-08-01 02:00:00       6.177980e+06            10371
#
#                                                                               \
#                     Taker buy base asset volume Taker buy quote asset volume
# Open time
# 2024-08-01 00:00:00                    31.14047                 2.011552e+06
# 2024-08-01 00:30:00                    25.19255                 1.627379e+06
# 2024-08-01 01:00:00                    17.58230                 1.135151e+06
# 2024-08-01 01:30:00                    27.28470                 1.753344e+06
# 2024-08-01 02:00:00                    45.36551                 2.905331e+06
#
#                       SOLUSDC   BTCUSDC  DOGEUSDC
#                       Returns   Returns   Returns
# Open time
# 2024-08-01 00:00:00 -0.001515 -0.001052  0.003199
# 2024-08-01 00:30:00  0.003327  0.001208  0.004416
# 2024-08-01 01:00:00 -0.000524 -0.001454 -0.002849
# 2024-08-01 01:30:00 -0.003609 -0.005393 -0.000490
# 2024-08-01 02:00:00 -0.009464 -0.003023 -0.013233
#
# [5 rows x 30 columns]

# %%
""" THESE ARE GLOBAL VARIABLES """
SQNC_LOOKBACK = 10
SQNC_RUNFORWARD = 100
ACTION_SIZE = 0 # set by sqnc_rtns_getters
STATE_DATA_SIZE = 0 # set by sqnc_rtns_getters
STATE_INTERNAL_SIZE = 0
REWARD_DECAY = 0.8
REWARD_ZEROS_PENALTY = -1
""" OKAY??? GLOBAL!!! """


def sqnc_rtns_getters():
    global ACTION_SIZE, STATE_DATA_SIZE, TICKERS

    df = getData()
    ACTION_SIZE = len(TICKERS)

    df = add_financial_indicators(df)

    normalized_df = df.copy()
    for drop_column in ["Returns"]:
        normalized_df = normalized_df.drop(columns=[(ticker, drop_column) for ticker in TICKERS])
    normalized_df.columns = ['_'.join(col).strip() for col in normalized_df.columns.values]
    scaler = preprocessing.MinMaxScaler()
    normalized_columns = scaler.fit_transform(normalized_df)
    normalized_df = pd.DataFrame(normalized_columns, columns=normalized_df.columns, index=normalized_df.index)

    state_df = normalized_df.copy()
    # display(state_df.head())

    lookback_states = df.copy()
    for column in lookback_states.columns:
        if "Returns" not in column:
            lookback_states.drop(columns=[column], inplace=True)
    lookback_states.columns = ['_'.join(col).strip() for col in lookback_states.columns.values]
    lookback_dfs = [lookback_states.shift(i) for i in range(SQNC_LOOKBACK)]
    lookback_df = pd.concat(lookback_dfs, axis=1)
    # display(lookback_df.head())

    STATE_DATA_SIZE = len(normalized_df.columns) + len(lookback_df.columns)

    testing_index = int(len(df) * 0.8)
    def getSequence(testing=False, training=False, tryAll=False, seed=None):
        state_arrays = state_df.values
        lookback_arrays = lookback_df.values
        indices = np.arange(len(state_arrays))

        if testing:
            indices = indices[testing_index:-1]
        elif training:
            if seed:
                rng = np.random.default_rng(seed)
                randomStart = rng.integers(SQNC_LOOKBACK, testing_index - SQNC_RUNFORWARD)
            else:
                randomStart = np.random.randint(SQNC_LOOKBACK, testing_index - SQNC_RUNFORWARD)
            indices = indices[randomStart:randomStart + SQNC_RUNFORWARD]
        elif tryAll:
            indices = indices[SQNC_LOOKBACK:]
        
        blankDf = pd.DataFrame(np.zeros((len(indices), ACTION_SIZE)), index=indices)
        blankDf[:] = np.nan
        def state_generator():
            for i in indices:
                yield np.concatenate([state_arrays[i], lookback_arrays[i]])
            yield None # a courtesy most generators do not supply
            
        return { 'actions_notebook': blankDf, 'state_gen': state_generator() }

    
    def getReturns(actions):
        # actions is a time_indices-indexed df of portfolio weights, just one column for now
        returns = []
        for a_i, i in enumerate(actions.index):
            if np.isnan(actions.iloc[a_i, 0]):
                break

            period_return = 0
            for j, ticker in enumerate(TICKERS):
                period_return += actions.iloc[a_i, j] * df.iloc[i][(ticker, "Returns")]
            returns.append(period_return)
        return returns
    
    return getSequence, getReturns
    

getSequence, getReturns = sqnc_rtns_getters()

# %%
notebook = getSequence(testing=True)['actions_notebook']
notebook.head()

# for ticker in TICKERS:
#     df = add_financial_indicators(getData())
#     testingIndex = int(len(df) * 0.8)
#     df = df.iloc[testingIndex:]
#     plt.plot(np.cumsum(df[(ticker, "Returns")]), label=ticker)
# plt.show()

for i, ticker in enumerate(TICKERS):
    notebook.iloc[:, :] = 0
    notebook.iloc[:, i] = 1
    plt.plot(np.cumsum(getReturns(notebook)), label=ticker)

notebook.iloc[:, :] = 1/ACTION_SIZE
plt.plot(np.cumsum(getReturns(notebook)), label='Equal Weighted Portfolio')
plt.title("Cumulative Returns (Testing Period)")
plt.legend()

# %%
def setFirstNA(df, value):
    first_na_index = df[df.isna().any(axis=1)].index[0]
    df.loc[first_na_index] = value
    return df

class PortfolioEnv(Env):
    def __init__(self, seed=None, testing=False):
        super(PortfolioEnv, self).__init__()

        global ACTION_SIZE, STATE_DATA_SIZE, STATE_INTERNAL_SIZE

        self.action_space = Box(low=0, high=1, shape=(ACTION_SIZE,), dtype=np.float64)
        self.observation_space = Box(low=0, high=1, shape=(STATE_DATA_SIZE + STATE_INTERNAL_SIZE,), dtype=np.float64)
        
        self.testing = testing
        self.training = 1 - self.testing
        d = getSequence(training=self.training, testing=self.testing, seed=seed)
        self.sequenceGen = d['state_gen']
        self.actionsNotebook = d['actions_notebook']
        self.state = self.sequenceGen.__next__()

    def step(self, action):
        global REWARD_DECAY, REWARD_ZEROS_PENALTY

        action = action / (np.sum(action) if np.sum(action) != 0 else 1)
        setFirstNA(self.actionsNotebook, action)
        
        returns = getReturns(self.actionsNotebook)
        reward = np.sum([r * REWARD_DECAY**i for i, r in enumerate(returns[::-1])])
        if np.sum(action) == 0:
            reward = REWARD_ZEROS_PENALTY
        
        self.state = self.sequenceGen.__next__()
        terminated = False
        truncated = False if self.state is not None else True
        return self.state, reward, terminated, truncated, {}

    def reset(self, seed=None, testing=False):
        super().reset(seed=seed)
        
        d = getSequence(training=self.training, testing=self.testing, seed=seed)
        self.sequenceGen = d['state_gen']
        self.actionsNotebook = d['actions_notebook']
        self.state = self.sequenceGen.__next__()
        return self.state, {}
    
env = DummyVecEnv([lambda: callbacks.CustomMonitor(PortfolioEnv(), 'callbacks/')])

# %%
SQNC_LOOKBACK = 10
SQNC_RUNFORWARD = 200
REWARD_DECAY = 0.95
REWARD_ZEROS_PENALTY = -0.1
model = RecurrentPPO("MlpLstmPolicy",
    env=env,
    verbose=1,
    n_steps=SQNC_RUNFORWARD,  # Episode length
    batch_size=SQNC_RUNFORWARD,
    n_epochs=10,
    learning_rate=0.0001,
    ent_coef=0.01,
    policy_kwargs={"lstm_hidden_size": 128}  # Optional: customize LSTM
)

callbacks.startDualWrite('callbacks/monitor.txt')
model.learn(total_timesteps=50000)
callbacks.stopDualWrite()
# Out:
# Using cpu device
# ----------------------------
# | time/              |     |
# |    fps             | 13  |
# |    iterations      | 1   |
# |    time_elapsed    | 14  |
# |    total_timesteps | 200 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 2             |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 400           |
# | train/                  |               |
# |    approx_kl            | 3.7592352e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.0146       |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0144       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000843     |
# |    std                  | 1             |
# |    value_loss           | 0.0906        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 3             |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 600           |
# | train/                  |               |
# |    approx_kl            | 2.2176802e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.000705     |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0259       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000131     |
# |    std                  | 1             |
# |    value_loss           | 0.039         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 4            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 800          |
# | train/                  |              |
# |    approx_kl            | 3.639251e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00918     |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0278      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000614    |
# |    std                  | 1            |
# |    value_loss           | 0.0315       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 5             |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 1000          |
# | train/                  |               |
# |    approx_kl            | 2.9129982e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.0877       |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.00895      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000648     |
# |    std                  | 1             |
# |    value_loss           | 0.0815        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 6            |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 1200         |
# | train/                  |              |
# |    approx_kl            | 9.949744e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0981      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0225      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000851    |
# |    std                  | 1            |
# |    value_loss           | 0.0476       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 7             |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 1400          |
# | train/                  |               |
# |    approx_kl            | 0.00020317525 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.00748      |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0294       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00155      |
# |    std                  | 1             |
# |    value_loss           | 0.0388        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 8             |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 1600          |
# | train/                  |               |
# |    approx_kl            | 0.00024222434 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.165        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0375       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00047      |
# |    std                  | 1             |
# |    value_loss           | 0.0131        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 9            |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 1800         |
# | train/                  |              |
# |    approx_kl            | 4.670471e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0215      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0294      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00032     |
# |    std                  | 1            |
# |    value_loss           | 0.0287       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 10            |
# |    time_elapsed         | 196           |
# |    total_timesteps      | 2000          |
# | train/                  |               |
# |    approx_kl            | 0.00011565715 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.27         |
# |    explained_variance   | 0.0469        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0252       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000253     |
# |    std                  | 1             |
# |    value_loss           | 0.0492        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 11            |
# |    time_elapsed         | 215           |
# |    total_timesteps      | 2200          |
# | train/                  |               |
# |    approx_kl            | 0.00048493026 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.27         |
# |    explained_variance   | -0.0391       |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0237       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00202      |
# |    std                  | 1             |
# |    value_loss           | 0.0464        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 12            |
# |    time_elapsed         | 235           |
# |    total_timesteps      | 2400          |
# | train/                  |               |
# |    approx_kl            | 0.00080043374 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.27         |
# |    explained_variance   | -0.0896       |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0312       |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00188      |
# |    std                  | 1             |
# |    value_loss           | 0.0318        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 13           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 2600         |
# | train/                  |              |
# |    approx_kl            | 0.0019573811 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.0217      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0375      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 1            |
# |    value_loss           | 0.0229       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 14          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 2800        |
# | train/                  |             |
# |    approx_kl            | 0.003826204 |
# |    clip_fraction        | 0.0015      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.0173     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0329     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00374    |
# |    std                  | 1           |
# |    value_loss           | 0.042       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 15           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 3000         |
# | train/                  |              |
# |    approx_kl            | 0.0060400646 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0211      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0269      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 1            |
# |    value_loss           | 0.0353       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 16          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.003562552 |
# |    clip_fraction        | 0.002       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00853     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0206     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 1           |
# |    value_loss           | 0.054       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 17          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 3400        |
# | train/                  |             |
# |    approx_kl            | 0.010773558 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0324     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.042      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.005      |
# |    std                  | 1           |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 18           |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 3600         |
# | train/                  |              |
# |    approx_kl            | 0.0024380798 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0325      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0292      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00328     |
# |    std                  | 1            |
# |    value_loss           | 0.0724       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 19           |
# |    time_elapsed         | 367          |
# |    total_timesteps      | 3800         |
# | train/                  |              |
# |    approx_kl            | 0.0018332544 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.101       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0366      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0012      |
# |    std                  | 1            |
# |    value_loss           | 0.023        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 20          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.010913875 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0541     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0435     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00362    |
# |    std                  | 1           |
# |    value_loss           | 0.00824     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 21           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 4200         |
# | train/                  |              |
# |    approx_kl            | 0.0041393377 |
# |    clip_fraction        | 0.009        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0843       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00545     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00621     |
# |    std                  | 1            |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 22           |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 4400         |
# | train/                  |              |
# |    approx_kl            | 0.0033783214 |
# |    clip_fraction        | 0.0025       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.116       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.012       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 1            |
# |    value_loss           | 0.082        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 23           |
# |    time_elapsed         | 441          |
# |    total_timesteps      | 4600         |
# | train/                  |              |
# |    approx_kl            | 0.0024588492 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00892     |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0368      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00132     |
# |    std                  | 1            |
# |    value_loss           | 0.0252       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 24           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 0.0039168657 |
# |    clip_fraction        | 0.005        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0614      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0365      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 1            |
# |    value_loss           | 0.0305       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 25           |
# |    time_elapsed         | 480          |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 0.0028700018 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.113       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.036       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 1            |
# |    value_loss           | 0.0566       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 26           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 5200         |
# | train/                  |              |
# |    approx_kl            | 0.0015644393 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0444       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0354      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000306    |
# |    std                  | 1            |
# |    value_loss           | 0.0174       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 27         |
# |    time_elapsed         | 518        |
# |    total_timesteps      | 5400       |
# | train/                  |            |
# |    approx_kl            | 0.00222662 |
# |    clip_fraction        | 0.0005     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.0428     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00257    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00133   |
# |    std                  | 0.999      |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 28           |
# |    time_elapsed         | 538          |
# |    total_timesteps      | 5600         |
# | train/                  |              |
# |    approx_kl            | 0.0058732526 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.0729      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0388      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00777     |
# |    std                  | 0.999        |
# |    value_loss           | 0.0496       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 29           |
# |    time_elapsed         | 557          |
# |    total_timesteps      | 5800         |
# | train/                  |              |
# |    approx_kl            | 0.0038829788 |
# |    clip_fraction        | 0.006        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.118       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0386      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.999        |
# |    value_loss           | 0.0158       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 30            |
# |    time_elapsed         | 577           |
# |    total_timesteps      | 6000          |
# | train/                  |               |
# |    approx_kl            | 0.00045176447 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.25         |
# |    explained_variance   | 0.0534        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0371       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.000236      |
# |    std                  | 0.999         |
# |    value_loss           | 0.014         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 31           |
# |    time_elapsed         | 599          |
# |    total_timesteps      | 6200         |
# | train/                  |              |
# |    approx_kl            | 0.0026924831 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0244       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00332     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 0.999        |
# |    value_loss           | 0.089        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 32           |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0056983577 |
# |    clip_fraction        | 0.0055       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.053        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0413      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0067      |
# |    std                  | 0.999        |
# |    value_loss           | 0.034        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 33           |
# |    time_elapsed         | 640          |
# |    total_timesteps      | 6600         |
# | train/                  |              |
# |    approx_kl            | 0.0025076224 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.0601      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0248      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000569    |
# |    std                  | 0.999        |
# |    value_loss           | 0.0593       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 34           |
# |    time_elapsed         | 659          |
# |    total_timesteps      | 6800         |
# | train/                  |              |
# |    approx_kl            | 0.0032202317 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0576       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.031       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00198     |
# |    std                  | 1            |
# |    value_loss           | 0.0336       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 35           |
# |    time_elapsed         | 678          |
# |    total_timesteps      | 7000         |
# | train/                  |              |
# |    approx_kl            | 0.0033203675 |
# |    clip_fraction        | 0.0035       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0398       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0425      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00408     |
# |    std                  | 1            |
# |    value_loss           | 0.0179       |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 36        |
# |    time_elapsed         | 699       |
# |    total_timesteps      | 7200      |
# | train/                  |           |
# |    approx_kl            | 0.0007027 |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.26     |
# |    explained_variance   | 0.0547    |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.00556  |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0.000416  |
# |    std                  | 1         |
# |    value_loss           | 0.0746    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 37         |
# |    time_elapsed         | 719        |
# |    total_timesteps      | 7400       |
# | train/                  |            |
# |    approx_kl            | 0.00332131 |
# |    clip_fraction        | 0.002      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.0447     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0293    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00421   |
# |    std                  | 1          |
# |    value_loss           | 0.0484     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 38           |
# |    time_elapsed         | 739          |
# |    total_timesteps      | 7600         |
# | train/                  |              |
# |    approx_kl            | 0.0015985116 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0167       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0296      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000337    |
# |    std                  | 1            |
# |    value_loss           | 0.0308       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 39           |
# |    time_elapsed         | 759          |
# |    total_timesteps      | 7800         |
# | train/                  |              |
# |    approx_kl            | 0.0029089374 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.00201      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0416      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 1            |
# |    value_loss           | 0.011        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 40            |
# |    time_elapsed         | 778           |
# |    total_timesteps      | 8000          |
# | train/                  |               |
# |    approx_kl            | 0.00086549076 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | 0.0716        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0398       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000134     |
# |    std                  | 1             |
# |    value_loss           | 0.00817       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 41           |
# |    time_elapsed         | 797          |
# |    total_timesteps      | 8200         |
# | train/                  |              |
# |    approx_kl            | 0.0015770831 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0438       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0376      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 1            |
# |    value_loss           | 0.0174       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 42          |
# |    time_elapsed         | 816         |
# |    total_timesteps      | 8400        |
# | train/                  |             |
# |    approx_kl            | 0.004396241 |
# |    clip_fraction        | 0.0045      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0483      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0462     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 1           |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 43           |
# |    time_elapsed         | 838          |
# |    total_timesteps      | 8600         |
# | train/                  |              |
# |    approx_kl            | 0.0018333682 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0637       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0363      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000678    |
# |    std                  | 1            |
# |    value_loss           | 0.0203       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 44           |
# |    time_elapsed         | 859          |
# |    total_timesteps      | 8800         |
# | train/                  |              |
# |    approx_kl            | 0.0014030394 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0431       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0381      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000673    |
# |    std                  | 1            |
# |    value_loss           | 0.013        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 45           |
# |    time_elapsed         | 880          |
# |    total_timesteps      | 9000         |
# | train/                  |              |
# |    approx_kl            | 0.0007520637 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0222       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0298      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000545    |
# |    std                  | 1            |
# |    value_loss           | 0.03         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 46            |
# |    time_elapsed         | 900           |
# |    total_timesteps      | 9200          |
# | train/                  |               |
# |    approx_kl            | 0.00084415317 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.0723       |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0211       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000619     |
# |    std                  | 1             |
# |    value_loss           | 0.049         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 47           |
# |    time_elapsed         | 920          |
# |    total_timesteps      | 9400         |
# | train/                  |              |
# |    approx_kl            | 0.0023955298 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.071        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0354      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0038      |
# |    std                  | 1            |
# |    value_loss           | 0.0347       |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 48            |
# |    time_elapsed         | 941           |
# |    total_timesteps      | 9600          |
# | train/                  |               |
# |    approx_kl            | 0.00020657897 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.022        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0254       |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.00104       |
# |    std                  | 1             |
# |    value_loss           | 0.0415        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 49          |
# |    time_elapsed         | 960         |
# |    total_timesteps      | 9800        |
# | train/                  |             |
# |    approx_kl            | 0.002003237 |
# |    clip_fraction        | 0.001       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0242     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00285    |
# |    std                  | 1           |
# |    value_loss           | 0.0749      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 50          |
# |    time_elapsed         | 978         |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.000800162 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0248     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0213     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000199   |
# |    std                  | 1           |
# |    value_loss           | 0.0437      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 51         |
# |    time_elapsed         | 996        |
# |    total_timesteps      | 10200      |
# | train/                  |            |
# |    approx_kl            | 0.00297927 |
# |    clip_fraction        | 0.002      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | -0.219     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.042     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00311   |
# |    std                  | 1          |
# |    value_loss           | 0.0279     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 52          |
# |    time_elapsed         | 1013        |
# |    total_timesteps      | 10400       |
# | train/                  |             |
# |    approx_kl            | 0.002826152 |
# |    clip_fraction        | 0.0035      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0699      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0403     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 1           |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 53           |
# |    time_elapsed         | 1031         |
# |    total_timesteps      | 10600        |
# | train/                  |              |
# |    approx_kl            | 0.0019002924 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.168       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.012       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 1            |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 54            |
# |    time_elapsed         | 1050          |
# |    total_timesteps      | 10800         |
# | train/                  |               |
# |    approx_kl            | 0.00034469424 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | 0.0743        |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.0179       |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -6.66e-05     |
# |    std                  | 1             |
# |    value_loss           | 0.0459        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 55           |
# |    time_elapsed         | 1072         |
# |    total_timesteps      | 11000        |
# | train/                  |              |
# |    approx_kl            | 0.0020196873 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0375      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 1            |
# |    value_loss           | 0.0405       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 56         |
# |    time_elapsed         | 1093       |
# |    total_timesteps      | 11200      |
# | train/                  |            |
# |    approx_kl            | 0.00196956 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.0731     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0283    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.000899  |
# |    std                  | 1          |
# |    value_loss           | 0.0323     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 57           |
# |    time_elapsed         | 1116         |
# |    total_timesteps      | 11400        |
# | train/                  |              |
# |    approx_kl            | 0.0019170919 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0198      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000498    |
# |    std                  | 1            |
# |    value_loss           | 0.0495       |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#       5 model = RecurrentPPO("MlpLstmPolicy",
#       6     env=env,
#       7     verbose=1,
#    (...)
#      13     policy_kwargs={"lstm_hidden_size": 128}  # Optional: customize LSTM
#      14 )
#      16 callbacks.startDualWrite('callbacks/monitor.txt')
# ---> 17 model.learn(total_timesteps=50000)
#      18 callbacks.stopDualWrite()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sb3_contrib\ppo_recurrent\ppo_recurrent.py:450, in RecurrentPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     441 def learn(
#     442     self: SelfRecurrentPPO,
#     443     total_timesteps: int,
#    (...)
#     448     progress_bar: bool = False,
#     449 ) -> SelfRecurrentPPO:
# --> 450     return super().learn(
#     451         total_timesteps=total_timesteps,
#     452         callback=callback,
#     453         log_interval=log_interval,
#     454         tb_log_name=tb_log_name,
#     455         reset_num_timesteps=reset_num_timesteps,
#     456         progress_bar=progress_bar,
#     457     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sb3_contrib\ppo_recurrent\ppo_recurrent.py:252, in RecurrentPPO.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     249 if isinstance(self.action_space, spaces.Box):
#     250     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 252 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     254 self.num_timesteps += env.num_envs
#     256 # Give access to local variables
#
# File ~\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\Ian Chen-Adamczyk\crypto\WIP-rl-models\callbacks.py:81, in CustomMonitor.step(self, action)
#      80 def step(self, action):
# ---> 81     obs, reward, terminated, truncated, info = self.env.step(action)
#      82     # Hypothetically add training metrics here (not directly available)
#      83     if "explained_variance" in info:  # This won't work without extra work
#
# Cell In[5], line 28, in PortfolioEnv.step(self, action)
#      25 action = action / (np.sum(action) if np.sum(action) != 0 else 1)
#      26 setFirstNA(self.actionsNotebook, action)
# ---> 28 returns = getReturns(self.actionsNotebook)
#      29 reward = np.sum([r * REWARD_DECAY**i for i, r in enumerate(returns[::-1])])
#      30 if np.sum(action) == 0:
#
# Cell In[3], line 79, in sqnc_rtns_getters.<locals>.getReturns(actions)
#      77     period_return = 0
#      78     for j, ticker in enumerate(TICKERS):
# ---> 79         period_return += actions.iloc[a_i, j] * df.iloc[i][(ticker, "Returns")]
#      80     returns.append(period_return)
#      81 return returns
#
# File c:\ProgramData\miniforge3\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\ProgramData\miniforge3\lib\site-packages\pandas\core\indexing.py:1754, in _iLocIndexer._getitem_axis(self, key, axis)
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
# -> 1754 return self.obj._ixs(key, axis=axis)
#
# File c:\ProgramData\miniforge3\lib\site-packages\pandas\core\frame.py:3996, in DataFrame._ixs(self, i, axis)
#    3994 # irow
#    3995 if axis == 0:
# -> 3996     new_mgr = self._mgr.fast_xs(i)
#    3998     # if we are a copy, mark as such
#    3999     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File c:\ProgramData\miniforge3\lib\site-packages\pandas\core\internals\managers.py:958, in BlockManager.fast_xs(self, loc)
#     953     return cls(blocks, axes, verify_integrity=False)
#     955 # ----------------------------------------------------------------
#     956 # Indexing
# --> 958 def fast_xs(self, loc: int) -> SingleBlockManager:
#     959     """
#     960     Return the array corresponding to `frame.iloc[loc]`.
#     961
#    (...)
#     968     np.ndarray or ExtensionArray
#     969     """
#     970     if len(self.blocks) == 1:
#     971         # TODO: this could be wrong if blk.mgr_locs is not slice(None)-like;
#     972         #  is this ruled out in the general case?
#
# KeyboardInterrupt:
# [400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000, 2200, 2400, 2600, 2800, 3000, 3200, 3400, 3600, 3800, 4000, 4200, 4400, 4600, 4800, 5000, 5200, 5400, 5600, 5800, 6000, 6200, 6400, 6600, 6800, 7000, 7200, 7400, 7600, 7800, 8000, 8200, 8400, 8600, 8800, 9000, 9200, 9400, 9600, 9800, 10000, 10200, 10400, 10600, 10800, 11000, 11200, 11400] [-0.0146, -0.000705, -0.00918, -0.0877, -0.0981, -0.00748, -0.165, -0.0215, 0.0469, -0.0391, -0.0896, -0.0217, -0.0173, -0.0211, 0.00853, -0.0324, -0.0325, -0.101, -0.0541, 0.0843, -0.116, -0.00892, -0.0614, -0.113, 0.0444, 0.0428, -0.0729, -0.118, 0.0534, 0.0244, 0.053, -0.0601, 0.0576, 0.0398, 0.0547, 0.0447, 0.0167, 0.00201, 0.0716, 0.0438, 0.0483, 0.0637, 0.0431, 0.0222, -0.0723, 0.071, -0.022, 0.106, -0.0248, -0.219, 0.0699, -0.168, 0.0743, 0.118, 0.0731, 0.104]
# Step 100
# Step 200
# Step 300
# Step 400
# Step 500
# Step 600
# Step 700
# Step 800
# Step 900
# Step 1000
# Step 1100
# Step 1200
# Step 1300
# Step 1400
# Step 1500
# Step 1600

# %%
model.save("(2b) best-yet-10k-steps")

# %%
callbacks.plotExplainedVariance()

# %%
test_env = DummyVecEnv([lambda: PortfolioEnv(testing=True)])
obs = test_env.reset()
cumulativeReturns = []
actions = getSequence(testing=True)['actions_notebook']
sums = []
done = False
i = 0
while not done:
    i += 1
    if i % 100 == 0:
        print(f"Step {i}")
    action, _ = model.predict(obs, deterministic=True)
    sums.append(*action)
    obs, reward, done, _ = test_env.step(action)
    cumulativeReturns.append(reward)
    setFirstNA(actions, action)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14464\4111111906.py in ?()
#      10     if i % 100 == 0:
#      11         print(f"Step {i}")
#      12     action, _ = model.predict(obs, deterministic=True)
#      13     sums.append(*action)
# ---> 14     obs, reward, done, _ = test_env.step(action)
#      15     cumulativeReturns.append(reward)
#      16     setFirstNA(actions, action)
#
# ~\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in ?(self, actions)
#     218         :param actions: the action
#     219         :return: observation, reward, done, information
#     220         """
#     221         self.step_async(actions)
# --> 222         return self.step_wait()
#
# ~\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in ?(self)
#      56     def step_wait(self) -> VecEnvStepReturn:
#      57         # Avoid circular imports
#      58         for env_idx in range(self.num_envs):
# ---> 59             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60                 self.actions[env_idx]
#      61             )
#      62             # convert to SB3 VecEnv api
#
# ~\AppData\Local\Temp\ipykernel_14464\3395890548.py in ?(self, action)
#      24
#      25         action = action / (np.sum(action) if np.sum(action) != 0 else 1)
#      26         setFirstNA(self.actionsNotebook, action)
#      27
# ---> 28         returns = getReturns(self.actionsNotebook)
#      29         reward = np.sum([r * REWARD_DECAY**i for i, r in enumerate(returns[::-1])])
#      30         if np.sum(action) == 0:
#      31             reward = REWARD_ZEROS_PENALTY
#
# ~\AppData\Local\Temp\ipykernel_14464\2731566858.py in ?(actions)
#      75                 break
#      76
#      77             period_return = 0
#      78             for j, ticker in enumerate(TICKERS):
# ---> 79                 period_return += actions.iloc[a_i, j] * df.iloc[i][(ticker, "Returns")]
#      80             returns.append(period_return)
#      81         return returns
#
# c:\ProgramData\miniforge3\lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1187             axis = self.axis or 0
#    1188
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#
# c:\ProgramData\miniforge3\lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1750
#    1751             # validate the location
#    1752             self._validate_integer(key, axis)
#    1753
# -> 1754             return self.obj._ixs(key, axis=axis)
#
# c:\ProgramData\miniforge3\lib\site-packages\pandas\core\frame.py in ?(self, i, axis)
#    3996             new_mgr = self._mgr.fast_xs(i)
#    3997
#    3998             # if we are a copy, mark as such
#    3999             copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
# -> 4000             result = self._constructor_sliced_from_mgr(new_mgr, axes=new_mgr.axes)
#    4001             result._name = self.index[i]
#    4002             result = result.__finalize__(self)
#    4003             result._set_is_copy(self, copy=copy)
#
# c:\ProgramData\miniforge3\lib\site-packages\pandas\core\frame.py in ?(self, mgr, axes)
#     678     def _constructor_sliced_from_mgr(self, mgr, axes) -> Series:
#     679         ser = Series._from_mgr(mgr, axes)
# --> 680         ser._name = None  # caller is responsible for setting real name
#     681
#     682         if type(self) is DataFrame:
#     683             # This would also work `if self._constructor_sliced is Series`, but
#
# c:\ProgramData\miniforge3\lib\site-packages\pandas\core\generic.py in ?(self, name, value)
#    6316
#    6317         # if this fails, go on to more involved attribute setting
#    6318         # (note that this matches __getattr__, above).
#    6319         if name in self._internal_names_set:
# -> 6320             object.__setattr__(self, name, value)
#    6321         elif name in self._metadata:
#    6322             object.__setattr__(self, name, value)
#    6323         else:
#
# KeyboardInterrupt:

# %%
notebook = getSequence(testing=True)['actions_notebook']
notebook.head()

notebook.iloc[:, :] = 1/ACTION_SIZE
plt.plot(np.cumsum(getReturns(notebook)), label='Equal Weighted Portfolio')
plt.plot(np.cumsum(getReturns(actions)), label='RL Portfolio')
plt.title("Cumulative Returns (Testing Period)")
plt.legend()
plt.show()

for i in range(ACTION_SIZE): plt.hist(sums[i::ACTION_SIZE], bins=100, label=f"asset {i}")
plt.title("Distribution of Portfolio Weights")
plt.legend()
plt.show()

callback.explained_variance.plot()
# Out:
# c:\ProgramData\miniforge3\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 16
#      13 plt.legend()
#      14 plt.show()
# ---> 16 callback.explained_variance.plot()
#
# NameError: name 'callback' is not defined
