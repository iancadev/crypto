# %%
import data

former_giants = [
    "NEOUSDT", "DASHUSDT", "ZECUSDT", "XMRUSDT", "ETCUSDT",
    "DOGEUSDT", "VETUSDT", "ICXUSDT", "ONTUSDT", "QTUMUSDT",
    "ZILUSDT", "BATUSDT", "OMGUSDT", "NANOUSDT", "WAVESUSDT",
    "LSKUSDT", "STEEMUSDT", "STRATUSDT", "REPUSDT", "GNTUSDT",
    "SNTUSDT", "ARDRUSDT", "FCTUSDT", "MAIDUSDT", "DCRUSDT",
    "SYSUSDT", "NAVUSDT", "PIVXUSDT", "BTSUSDT", "XEMUSDT"
]

memecoins = [
    "DOGEUSDT", "SHIBUSDT", "SAFEMOONUSDT", "AKITAUSDT", "KISHUUSDT",
    "HOGEUSDT", "PIGUSDT", "ELONUSDT", "SAMOUSDT", "MONAUSDT",
    "FLOKIUSDT", "DOGELONUSDT", "BABYDOGEUSDT", "WOJAKUSDT", "PEPEUSDT",
    "TURBOUSDT", "MONGUSDT", "BONKUSDT", "PITUSDT", "CATEUSDT",
    "HUSKYUSDT", "SHIBAUSDT", "LEASHUSDT", "FLOKIPUPUSDT", "DOGGYUSDT",
    "SHIBAKENUSDT", "KLEEUSDT", "DOGIRAUSDT", "SHIBORGUSDT", "SHIBXUSDT"
]

volatile_tokens = [
    "SAFEMOONUSDT", "SAVETHEKIDSUSDT", "EBTCUSDT", "ETHEREUMCASHUSDT", "PUMPUSDT",
    "RUGUSDT", "MOONUSDT", "HYPEUSDT", "FOMOUSDT", "YOLOUSDT",
    "SCAMUSDT", "DUMPUSDT", "PONZIUSDT", "EXITUSDT", "BURNUSDT",
    "FLASHUSDT", "HITUSDT", "RUNUSDT", "JUMPUSDT", "FLIPUSDT",
    "SPINUSDT", "ROLLUSDT", "BOUNCEUSDT", "SWINGUSDT", "LEAPUSDT",
    "DIVEUSDT", "SOARUSDT", "CRASHUSDT", "FLYUSDT", "DROPUSDT"
]

transfer_learning_tokens = [
    "BTCUSDT",    # gold standard of crypto, benchmark
    "ETHUSDT",    # smart contract leader, fee-based dynamics
    "BNBUSDT",    # exchange coin, tied to Binance operations
    "ADAUSDT",    # slow dev cycle, retail-heavy
    "XRPUSDT",    # lawsuit-related swings, strong sentiment
    "SOLUSDT",    # high-speed L1, known for downtime
    "AVAXUSDT",   # deflationary model, eco-focus
    "MATICUSDT",  # scaling narrative, steady growth
    "DOTUSDT",    # interoperability play, slow burn
    "LINKUSDT",   # oracle narrative, DeFi-tied
    "LTCUSDT",    # old-school Bitcoin fork, halving effects
    "UNIUSDT",    # DeFi leader, DEX-centric
    "AAVEUSDT",   # lending protocol, TVL sensitivity
    "SUSHIUSDT",  # community forks, governance drama
    "YFIUSDT",    # founder drama, DeFi yield farming
    "FTMUSDT",    # smart contract platform, volatile runs
    "ALGOUSDT",   # techy L1, low user activity
    "ATOMUSDT",   # modular chain narrative
    "NEARUSDT",   # strong tech, big VC push
    "HBARUSDT",   # DAG model, high TPS claims
    "AXSUSDT",    # play-to-earn boom and bust
    "SANDUSDT",   # metaverse hype
    "MANAUSDT",   # virtual land trend
    "GALAUSDT",   # gaming token, volatile
    "ENSUSDT",    # identity-focused, clear trend reversals
    "STXUSDT",    # Bitcoin L2 narrative
    "RNDRUSDT",   # AI/rendering hype
    "INJUSDT",    # on-chain trading protocol
    "DYDXUSDT",   # perpetual DEX, funding rate effects
    "RUNEUSDT"    # Thorchain—cross-chain narrative
]


assets = former_giants + memecoins + volatile_tokens + transfer_learning_tokens

for i, asset in enumerate(assets):
    print(f"loading asset {i+1}/{len(assets)}: {asset}")
    try:
        data.load_asset(asset, sampling='30m')
        data.load_asset(asset, sampling='6h')
        data.load_asset(asset, sampling='1d')
    except Exception as e:
        print("Unable to download", asset)
        print(e)
        print()
        print()
# Out:
# loading asset 0/120: NEOUSDT
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2025-03.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2025-02.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2025-01.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-12.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-11.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-10.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-09.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-08.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-07.zip
# https://data.binance.vision/data/spot/monthly/klines/NEOUSDT/30m/NEOUSDT-30m-2024-06.zip
# ...

# %%
len(set(assets))
# Out:
# 118
