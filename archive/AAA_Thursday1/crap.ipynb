# %%
import importlib
from __imports__ import *
import data, LSTM_returns, optimization
importlib.reload(data)
# Out:
# <module 'data' from 'c:\\Users\\27904\\OneDrive\\桌面\\crypto\\AAA_Thursday1\\data\\__init__.py'>

# %%
DOGE = data.load_asset('DOGEUSDT', sampling='1d')
DOGE = data.add_fear_and_greed(DOGE)
DOGE = DOGE[DOGE.index >= '2022-01-01']

# %%
BTC = data.load_asset('BTCUSDT', sampling='1d')
BTC = data.add_fear_and_greed(BTC)
# Restrict data after 2022
BTC = BTC[BTC.index >= '2022-01-01']
BTC.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Quote asset volume',
#        'Number of trades', 'Taker buy base asset volume',
#        'Taker buy quote asset volume', 'F&G', 'F&G category'],
#       dtype='object')

# %%
SOL = data.load_asset('SOLUSDT', sampling='1d')
SOL = data.add_fear_and_greed(SOL)
# Restrict data after 2022
SOL = SOL[SOL.index >= '2022-01-01']

# %%
ETH = data.load_asset('ETHUSDT', sampling='1d')
ETH = data.add_fear_and_greed(ETH)
# Restrict data after 2022
ETH = ETH[ETH.index >= '2022-01-01']

# %%
XRP = data.load_asset('XRPUSDT', sampling='1d')
XRP = data.add_fear_and_greed(XRP)
# Restrict data after 2022
XRP = XRP[XRP.index >= '2022-01-01']
XRP.tail()
# Out:
#               Open    High     Low   Close       Volume  Quote asset volume  \
# Open time
# 2025-03-27  2.3494  2.3900  2.3021  2.3410  121906802.0        2.865171e+08
# 2025-03-28  2.3411  2.3433  2.1535  2.2073  211389681.0        4.705248e+08
# 2025-03-29  2.2072  2.2267  2.0607  2.1351  188344703.0        3.995656e+08
# 2025-03-30  2.1352  2.2142  2.1077  2.1369  143436566.0        3.095568e+08
# 2025-03-31  2.1371  2.1415  2.0238  2.0899  225359911.0        4.704750e+08
#
#             Number of trades  Taker buy base asset volume  \
# Open time
# 2025-03-27            940315                   60473620.0
# 2025-03-28           1469290                  105639152.0
# 2025-03-29           1392395                   91627450.0
# 2025-03-30           1092491                   71435902.0
# 2025-03-31           1771277                  114012792.0
#
#             Taker buy quote asset volume   F&G F&G category
# Open time
# 2025-03-27                  1.421305e+08  40.0         Fear
# 2025-03-28                  2.350883e+08  44.0         Fear
# 2025-03-29                  1.943217e+08  26.0         Fear
# 2025-03-30                  1.541902e+08  32.0         Fear
# 2025-03-31                  2.380228e+08  34.0         Fear

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- 1) Plot BTC & DOGE price series ----------------------------------------

import matplotlib.pyplot as plt

# Ensure your BTC and DOGE DataFrames are loaded and indexed by date
fig, ax1 = plt.subplots(figsize=(12, 5))

# Plot BTC on the left y-axis
color_btc = 'tab:blue'
ax1.set_xlabel('Date')
ax1.set_ylabel('BTCUSDT Close Price', color=color_btc)
ax1.plot(BTC.index, BTC['Close'], color=color_btc, label='BTCUSDT')
ax1.tick_params(axis='y', labelcolor=color_btc)

# Create a second y-axis for DOGE
ax2 = ax1.twinx()
color_doge = 'tab:orange'
ax2.set_ylabel('DOGEUSDT Close Price', color=color_doge)
ax2.plot(DOGE.index, DOGE['Close'], color=color_doge, label='DOGEUSDT')
ax2.tick_params(axis='y', labelcolor=color_doge)

# Combine legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title("BTC vs DOGE Daily Close Price (Dual Y-Axis)")
fig.tight_layout()
plt.show()

# %%
df_close = pd.DataFrame({
    'BTC':  BTC['Close'],
    'DOGE': DOGE['Close'],
    'ETH':  ETH['Close'],
    'SOL':  SOL['Close'],
    'XRP':  XRP['Close']
}).dropna()

corr_all = df_close.corr()

# %%
# numeric Fear & Greed column name – adjust if yours differs:
fg_col = 'F&G'

# grab the index series (should be same across assets)
fg_index = BTC[fg_col].reindex(df_close.index)

# high‐greed regime (>65)
mask_high = fg_index > 65
corr_high = df_close.loc[mask_high].corr()
print("\nCorrelation (F&G > 70):")
display(corr_high)

# fear regime (<45)
mask_low  = fg_index < 45
corr_low  = df_close.loc[mask_low].corr()
print("\nCorrelation (F&G < 39):")
display(corr_low)
# Out:
# Correlation (F&G > 70):
#            BTC      DOGE       ETH       SOL       XRP
# BTC   1.000000  0.929390  0.754213  0.946841  0.770458
# DOGE  0.929390  1.000000  0.609060  0.844351  0.817928
# ETH   0.754213  0.609060  1.000000  0.789011  0.356870
# SOL   0.946841  0.844351  0.789011  1.000000  0.601580
# XRP   0.770458  0.817928  0.356870  0.601580  1.000000
# Correlation (F&G < 39):
#            BTC      DOGE       ETH       SOL       XRP
# BTC   1.000000  0.794009  0.628597  0.894077  0.825552
# DOGE  0.794009  1.000000  0.691437  0.789575  0.799387
# ETH   0.628597  0.691437  1.000000  0.844838  0.315536
# SOL   0.894077  0.789575  0.844838  1.000000  0.594334
# XRP   0.825552  0.799387  0.315536  0.594334  1.000000

# %%
display_pretty_corr(corr_high, "Correlation (F&amp;G > 65)")
display_pretty_corr(corr_low,  "Correlation (F&amp;G < 45)")
# Out:
# <style type="text/css">
# #T_8dede caption {
#   color: #333;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_8dede_row0_col0, #T_8dede_row1_col1, #T_8dede_row2_col2, #T_8dede_row3_col3, #T_8dede_row4_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row0_col1, #T_8dede_row1_col0 {
#   background-color: #810823;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row0_col2, #T_8dede_row2_col0 {
#   background-color: #ba2832;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row0_col3, #T_8dede_row3_col0 {
#   background-color: #790622;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row0_col4, #T_8dede_row4_col0 {
#   background-color: #b72230;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row1_col2, #T_8dede_row2_col1, #T_8dede_row3_col4, #T_8dede_row4_col3 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row1_col3, #T_8dede_row3_col1 {
#   background-color: #9f1228;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row1_col4, #T_8dede_row4_col1 {
#   background-color: #ab162a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row2_col3, #T_8dede_row3_col2 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8dede_row2_col4, #T_8dede_row4_col2 {
#   background-color: #f6b191;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_8dede">
#   <caption>**Correlation (F&amp;G > 65)**</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dede_level0_col0" class="col_heading level0 col0" >BTC</th>
#       <th id="T_8dede_level0_col1" class="col_heading level0 col1" >DOGE</th>
#       <th id="T_8dede_level0_col2" class="col_heading level0 col2" >ETH</th>
#       <th id="T_8dede_level0_col3" class="col_heading level0 col3" >SOL</th>
#       <th id="T_8dede_level0_col4" class="col_heading level0 col4" >XRP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dede_level0_row0" class="row_heading level0 row0" >BTC</th>
#       <td id="T_8dede_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_8dede_row0_col1" class="data row0 col1" >0.93</td>
#       <td id="T_8dede_row0_col2" class="data row0 col2" >0.75</td>
#       <td id="T_8dede_row0_col3" class="data row0 col3" >0.95</td>
#       <td id="T_8dede_row0_col4" class="data row0 col4" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_8dede_level0_row1" class="row_heading level0 row1" >DOGE</th>
#       <td id="T_8dede_row1_col0" class="data row1 col0" >0.93</td>
#       <td id="T_8dede_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_8dede_row1_col2" class="data row1 col2" >0.61</td>
#       <td id="T_8dede_row1_col3" class="data row1 col3" >0.84</td>
#       <td id="T_8dede_row1_col4" class="data row1 col4" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_8dede_level0_row2" class="row_heading level0 row2" >ETH</th>
#       <td id="T_8dede_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_8dede_row2_col1" class="data row2 col1" >0.61</td>
#       <td id="T_8dede_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_8dede_row2_col3" class="data row2 col3" >0.79</td>
#       <td id="T_8dede_row2_col4" class="data row2 col4" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_8dede_level0_row3" class="row_heading level0 row3" >SOL</th>
#       <td id="T_8dede_row3_col0" class="data row3 col0" >0.95</td>
#       <td id="T_8dede_row3_col1" class="data row3 col1" >0.84</td>
#       <td id="T_8dede_row3_col2" class="data row3 col2" >0.79</td>
#       <td id="T_8dede_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_8dede_row3_col4" class="data row3 col4" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_8dede_level0_row4" class="row_heading level0 row4" >XRP</th>
#       <td id="T_8dede_row4_col0" class="data row4 col0" >0.77</td>
#       <td id="T_8dede_row4_col1" class="data row4 col1" >0.82</td>
#       <td id="T_8dede_row4_col2" class="data row4 col2" >0.36</td>
#       <td id="T_8dede_row4_col3" class="data row4 col3" >0.60</td>
#       <td id="T_8dede_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_750a2 caption {
#   color: #333;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_750a2_row0_col0, #T_750a2_row1_col1, #T_750a2_row2_col2, #T_750a2_row3_col3, #T_750a2_row4_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row0_col1, #T_750a2_row1_col0, #T_750a2_row1_col3, #T_750a2_row3_col1 {
#   background-color: #b3192c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row0_col2, #T_750a2_row2_col0 {
#   background-color: #d05548;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row0_col3, #T_750a2_row3_col0 {
#   background-color: #8d0c25;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row0_col4, #T_750a2_row4_col0 {
#   background-color: #a81529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row1_col2, #T_750a2_row2_col1 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row1_col4, #T_750a2_row4_col1 {
#   background-color: #b1182b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row2_col3, #T_750a2_row3_col2 {
#   background-color: #9f1228;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_750a2_row2_col4, #T_750a2_row4_col2 {
#   background-color: #f8bb9e;
#   color: #000000;
#   text-align: center;
# }
# #T_750a2_row3_col4, #T_750a2_row4_col3 {
#   background-color: #d6604d;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_750a2">
#   <caption>**Correlation (F&amp;G < 45)**</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_750a2_level0_col0" class="col_heading level0 col0" >BTC</th>
#       <th id="T_750a2_level0_col1" class="col_heading level0 col1" >DOGE</th>
#       <th id="T_750a2_level0_col2" class="col_heading level0 col2" >ETH</th>
#       <th id="T_750a2_level0_col3" class="col_heading level0 col3" >SOL</th>
#       <th id="T_750a2_level0_col4" class="col_heading level0 col4" >XRP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_750a2_level0_row0" class="row_heading level0 row0" >BTC</th>
#       <td id="T_750a2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_750a2_row0_col1" class="data row0 col1" >0.79</td>
#       <td id="T_750a2_row0_col2" class="data row0 col2" >0.63</td>
#       <td id="T_750a2_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_750a2_row0_col4" class="data row0 col4" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_750a2_level0_row1" class="row_heading level0 row1" >DOGE</th>
#       <td id="T_750a2_row1_col0" class="data row1 col0" >0.79</td>
#       <td id="T_750a2_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_750a2_row1_col2" class="data row1 col2" >0.69</td>
#       <td id="T_750a2_row1_col3" class="data row1 col3" >0.79</td>
#       <td id="T_750a2_row1_col4" class="data row1 col4" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_750a2_level0_row2" class="row_heading level0 row2" >ETH</th>
#       <td id="T_750a2_row2_col0" class="data row2 col0" >0.63</td>
#       <td id="T_750a2_row2_col1" class="data row2 col1" >0.69</td>
#       <td id="T_750a2_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_750a2_row2_col3" class="data row2 col3" >0.84</td>
#       <td id="T_750a2_row2_col4" class="data row2 col4" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_750a2_level0_row3" class="row_heading level0 row3" >SOL</th>
#       <td id="T_750a2_row3_col0" class="data row3 col0" >0.89</td>
#       <td id="T_750a2_row3_col1" class="data row3 col1" >0.79</td>
#       <td id="T_750a2_row3_col2" class="data row3 col2" >0.84</td>
#       <td id="T_750a2_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_750a2_row3_col4" class="data row3 col4" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_750a2_level0_row4" class="row_heading level0 row4" >XRP</th>
#       <td id="T_750a2_row4_col0" class="data row4 col0" >0.83</td>
#       <td id="T_750a2_row4_col1" class="data row4 col1" >0.80</td>
#       <td id="T_750a2_row4_col2" class="data row4 col2" >0.32</td>
#       <td id="T_750a2_row4_col3" class="data row4 col3" >0.59</td>
#       <td id="T_750a2_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
def display_pretty_corr(corr_df, title):
    """
    Displays a correlation matrix with a diverging background gradient,
    formatted to 2dp, and a caption.
    """
    styled = (
        corr_df
        .style
        .format("{:.2f}")
        # use a valid diverging cmap, e.g. RdBu_r for red=positive, blue=negative
        .background_gradient(cmap="RdBu_r", vmin=-1, vmax=1, axis=None)
        .set_caption(f"**{title}**")
        .set_table_styles([
            {"selector": "caption",
             "props": [("color", "#333"),
                       ("font-size", "14pt"),
                       ("font-weight", "bold")]}
        ])
        .set_properties(**{"text-align": "center"})
    )
    display(styled)

# Then call it on your three matrices:
display_pretty_corr(corr_all,  "Correlation Matrix — All Dates")
# Out:
# <style type="text/css">
# #T_d47b1 caption {
#   color: #333;
#   font-size: 14pt;
#   font-weight: bold;
# }
# #T_d47b1_row0_col0, #T_d47b1_row1_col1, #T_d47b1_row2_col2, #T_d47b1_row3_col3, #T_d47b1_row4_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row0_col1, #T_d47b1_row1_col0 {
#   background-color: #9c1127;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row0_col2, #T_d47b1_row2_col0 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row0_col3, #T_d47b1_row3_col0 {
#   background-color: #7c0722;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row0_col4, #T_d47b1_row4_col0 {
#   background-color: #b72230;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row1_col2, #T_d47b1_row2_col1 {
#   background-color: #c6413e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row1_col3, #T_d47b1_row3_col1 {
#   background-color: #a81529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row1_col4, #T_d47b1_row4_col1 {
#   background-color: #b1182b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row2_col3, #T_d47b1_row3_col2 {
#   background-color: #960f27;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_d47b1_row2_col4, #T_d47b1_row4_col2 {
#   background-color: #f3a481;
#   color: #000000;
#   text-align: center;
# }
# #T_d47b1_row3_col4, #T_d47b1_row4_col3 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_d47b1">
#   <caption>**Correlation Matrix — All Dates**</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d47b1_level0_col0" class="col_heading level0 col0" >BTC</th>
#       <th id="T_d47b1_level0_col1" class="col_heading level0 col1" >DOGE</th>
#       <th id="T_d47b1_level0_col2" class="col_heading level0 col2" >ETH</th>
#       <th id="T_d47b1_level0_col3" class="col_heading level0 col3" >SOL</th>
#       <th id="T_d47b1_level0_col4" class="col_heading level0 col4" >XRP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d47b1_level0_row0" class="row_heading level0 row0" >BTC</th>
#       <td id="T_d47b1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d47b1_row0_col1" class="data row0 col1" >0.85</td>
#       <td id="T_d47b1_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_d47b1_row0_col3" class="data row0 col3" >0.94</td>
#       <td id="T_d47b1_row0_col4" class="data row0 col4" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_d47b1_level0_row1" class="row_heading level0 row1" >DOGE</th>
#       <td id="T_d47b1_row1_col0" class="data row1 col0" >0.85</td>
#       <td id="T_d47b1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d47b1_row1_col2" class="data row1 col2" >0.68</td>
#       <td id="T_d47b1_row1_col3" class="data row1 col3" >0.82</td>
#       <td id="T_d47b1_row1_col4" class="data row1 col4" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_d47b1_level0_row2" class="row_heading level0 row2" >ETH</th>
#       <td id="T_d47b1_row2_col0" class="data row2 col0" >0.79</td>
#       <td id="T_d47b1_row2_col1" class="data row2 col1" >0.68</td>
#       <td id="T_d47b1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_d47b1_row2_col3" class="data row2 col3" >0.87</td>
#       <td id="T_d47b1_row2_col4" class="data row2 col4" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_d47b1_level0_row3" class="row_heading level0 row3" >SOL</th>
#       <td id="T_d47b1_row3_col0" class="data row3 col0" >0.94</td>
#       <td id="T_d47b1_row3_col1" class="data row3 col1" >0.82</td>
#       <td id="T_d47b1_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_d47b1_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_d47b1_row3_col4" class="data row3 col4" >0.61</td>
#     </tr>
#     <tr>
#       <th id="T_d47b1_level0_row4" class="row_heading level0 row4" >XRP</th>
#       <td id="T_d47b1_row4_col0" class="data row4 col0" >0.77</td>
#       <td id="T_d47b1_row4_col1" class="data row4 col1" >0.80</td>
#       <td id="T_d47b1_row4_col2" class="data row4 col2" >0.41</td>
#       <td id="T_d47b1_row4_col3" class="data row4 col3" >0.61</td>
#       <td id="T_d47b1_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
