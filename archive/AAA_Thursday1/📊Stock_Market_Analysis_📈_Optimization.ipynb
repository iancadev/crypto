# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import data as DATADATA

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Scale the data
from sklearn.preprocessing import MinMaxScaler


for ticker in ['SOLUSDT', 'BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'DOGEUSDT']:

    df = DATADATA.load_asset(ticker, sampling='1d')
    df = DATADATA.subset(df, start=pd.Timestamp('2022-01-01'), end=pd.Timestamp('2024-03-01'))


    # Create a new dataframe with only the 'Close column
    df['Returns'] = df['Close'].pct_change()
    df.dropna(inplace=True)
    data = df.filter(['Returns'])
    dataset = data.values

    # Convert the dataframe to a numpy array
    scaler = MinMaxScaler(feature_range=(0,1))
    scaled_data = scaler.fit_transform(dataset)

    scaled_data

    # Create the training data set
    # Create the scaled training data set
    train_data = scaled_data
    # Split the data into x_train and y_train data sets
    x_train = []
    y_train = []

    for i in range(60, len(train_data)):
        x_train.append(train_data[i-60:i, 0])
        y_train.append(train_data[i, 0])
        if i<= 61:
            print(x_train)
            print(y_train)
            print()

    # Convert the x_train and y_train to numpy arrays
    x_train, y_train = np.array(x_train), np.array(y_train)

    # Reshape the data
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    # x_train.shape

    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(25))
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    model.fit(x_train, y_train, batch_size=8, epochs=16)

    # Get the models predicted price values
    predictions = model.predict(x_train)
    predictions = scaler.inverse_transform(predictions)

    # Get the root mean squared error (RMSE)
    rmse = np.sqrt(np.mean(((predictions - y_train) ** 2)))
    rmse


    valid = data[60:]
    valid['Predictions'] = predictions
    display(valid.head(10))

    # Save the model
    model.save(f'models-KaggleSMA/lstm_model_{ticker}.keras')
# Out:
# [array([0.54472761, 0.51795175, 0.5458684 , 0.45971998, 0.52809911,
#        0.44206164, 0.62073118, 0.55254793, 0.51786495, 0.60768529,
#        0.6728449 , 0.5175695 , 0.56524117, 0.57841529, 0.56804625,
#        0.49104536, 0.5785498 , 0.50843425, 0.48873481, 0.40485906,
#        0.35378105, 0.63908658, 0.45975946, 0.60482438, 0.52894637,
#        0.52707829, 0.59230667, 0.63509503, 0.52545923, 0.65384089,
#        0.70650308, 0.46602662, 0.5635228 , 0.70753701, 0.57838448,
#        0.58295368, 0.5912991 , 0.51832429, 0.57062456, 0.47388248,
#        0.44354546, 0.5570702 , 0.5216266 , 0.61566339, 0.69193589,
#        0.51858293, 0.45547483, 0.51263121, 0.58594986, 0.55690816,
#        0.45057931, 0.62009521, 0.53725521, 0.64037486, 0.61509933,
#        0.52919456, 0.49679149, 0.78438335, 0.5512827 , 0.59234641])]
# [np.float64(0.4977577805011001)]
#
# [array([0.54472761, 0.51795175, 0.5458684 , 0.45971998, 0.52809911,
#        0.44206164, 0.62073118, 0.55254793, 0.51786495, 0.60768529,
#        0.6728449 , 0.5175695 , 0.56524117, 0.57841529, 0.56804625,
#        0.49104536, 0.5785498 , 0.50843425, 0.48873481, 0.40485906,
#        0.35378105, 0.63908658, 0.45975946, 0.60482438, 0.52894637,
#        0.52707829, 0.59230667, 0.63509503, 0.52545923, 0.65384089,
#        0.70650308, 0.46602662, 0.5635228 , 0.70753701, 0.57838448,
#        0.58295368, 0.5912991 , 0.51832429, 0.57062456, 0.47388248,
#        0.44354546, 0.5570702 , 0.5216266 , 0.61566339, 0.69193589,
#        0.51858293, 0.45547483, 0.51263121, 0.58594986, 0.55690816,
#        0.45057931, 0.62009521, 0.53725521, 0.64037486, 0.61509933,
#        0.52919456, 0.49679149, 0.78438335, 0.5512827 , 0.59234641]), array([0.51795175, 0.5458684 , 0.45971998, 0.52809911, 0.44206164,
#        0.62073118, 0.55254793, 0.51786495, 0.60768529, 0.6728449 ,
#        0.5175695 , 0.56524117, 0.57841529, 0.56804625, 0.49104536,
#        0.5785498 , 0.50843425, 0.48873481, 0.40485906, 0.35378105,
#        0.63908658, 0.45975946, 0.60482438, 0.52894637, 0.52707829,
#        0.59230667, 0.63509503, 0.52545923, 0.65384089, 0.70650308,
#        0.46602662, 0.5635228 , 0.70753701, 0.57838448, 0.58295368,
#        0.5912991 , 0.51832429, 0.57062456, 0.47388248, 0.44354546,
#        0.5570702 , 0.5216266 , 0.61566339, 0.69193589, 0.51858293,
#        0.45547483, 0.51263121, 0.58594986, 0.55690816, 0.45057931,
#        0.62009521, 0.53725521, 0.64037486, 0.61509933, 0.52919456,
#        0.49679149, 0.78438335, 0.5512827 , 0.59234641, 0.49775778])]
# [np.float64(0.4977577805011001), np.float64(0.46287425211901534)]
#
# Epoch 1/16
# c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0383
# Epoch 2/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0056
# Epoch 3/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0066
# Epoch 4/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0068
# Epoch 5/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0057
# Epoch 6/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0061
# Epoch 7/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0070
# Epoch 8/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0060
# Epoch 9/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0054
# Epoch 10/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0058
# Epoch 11/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0059
# Epoch 12/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0066
# Epoch 13/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0067
# Epoch 14/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0053
# Epoch 15/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0063
# Epoch 16/16
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0058
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 66
#      63 model.fit(x_train, y_train, batch_size=8, epochs=16)
#      65 # Get the models predicted price values
# ---> 66 predictions = model.predict(x_train)
#      67 predictions = scaler.inverse_transform(predictions)
#      69 # Get the root mean squared error (RMSE)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:560, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     558 callbacks.on_predict_batch_begin(step)
#     559 data = get_data(iterator)
# --> 560 batch_outputs = self.predict_function(data)
#     561 outputs = append_to_outputs(batch_outputs, outputs)
#     562 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:259, in TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed(data)
#     256 @tf.autograph.experimental.do_not_convert
#     257 def one_step_on_data_distributed(data):
#     258     data = data[0]
# --> 259     outputs = self.distribute_strategy.run(
#     260         one_step_on_data, args=(data,)
#     261     )
#     262     outputs = reduce_per_replica(
#     263         outputs,
#     264         self.distribute_strategy,
#     265         reduction="concat",
#     266     )
#     267     return outputs
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:249, in TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data(data)
#     246 @tf.autograph.experimental.do_not_convert
#     247 def one_step_on_data(data):
#     248     """Runs a predict test step on a batch of data."""
# --> 249     return self.predict_step(data)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:104, in TensorFlowTrainer.predict_step(self, data)
#     102 x, _, _ = data_adapter_utils.unpack_x_y_sample_weight(data)
#     103 if self._call_has_training_arg:
# --> 104     y_pred = self(x, training=False)
#     105 else:
#     106     y_pred = self(x)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\layer.py:910, in Layer.__call__(self, *args, **kwargs)
#     908         outputs = super().__call__(*args, **kwargs)
#     909 else:
# --> 910     outputs = super().__call__(*args, **kwargs)
#     911 # Change the layout for the layer output if needed.
#     912 # This is useful for relayout intermediate tensor in the model
#     913 # to achieve the optimal performance.
#     914 distribution = distribution_lib.distribution()
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\ops\operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\models\sequential.py:221, in Sequential.call(self, inputs, training, mask)
#     219 def call(self, inputs, training=None, mask=None):
#     220     if self._functional:
# --> 221         return self._functional.call(inputs, training=training, mask=mask)
#     223     # Fallback: Just apply the layer sequence.
#     224     # This typically happens if `inputs` is a nested struct.
#     225     for layer in self.layers:
#     226         # During each iteration, `inputs` are the inputs to `layer`, and
#     227         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     228         # end of each iteration `inputs` is set to `outputs` to prepare for
#     229         # the next layer.
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\models\functional.py:183, in Functional.call(self, inputs, training, mask)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     185 )
#     186 return unpack_singleton(outputs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\ops\function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\models\functional.py:643, in operation_fn.<locals>.call(*args, **kwargs)
#     637 if (
#     638     hasattr(operation, "_call_has_training_arg")
#     639     and operation._call_has_training_arg
#     640     and training is not None
#     641 ):
#     642     kwargs["training"] = training
# --> 643 return operation(*args, **kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\layer.py:910, in Layer.__call__(self, *args, **kwargs)
#     908         outputs = super().__call__(*args, **kwargs)
#     909 else:
# --> 910     outputs = super().__call__(*args, **kwargs)
#     911 # Change the layout for the layer output if needed.
#     912 # This is useful for relayout intermediate tensor in the model
#     913 # to achieve the optimal performance.
#     914 distribution = distribution_lib.distribution()
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\ops\operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:584, in LSTM.call(self, sequences, initial_state, mask, training)
#     583 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 584     return super().call(
#     585         sequences, mask=mask, training=training, initial_state=initial_state
#     586     )
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:408, in RNN.call(self, sequences, initial_state, mask, training)
#     402 # Prepopulate the dropout state so that the inner_loop is stateless
#     403 # this is particularly important for JAX backend.
#     404 self._maybe_config_dropout_masks(
#     405     self.cell, sequences[:, 0, :], initial_state
#     406 )
# --> 408 last_output, outputs, states = self.inner_loop(
#     409     sequences=sequences,
#     410     initial_state=initial_state,
#     411     mask=mask,
#     412     training=training,
#     413 )
#     414 last_output = ops.cast(last_output, self.compute_dtype)
#     415 outputs = ops.cast(outputs, self.compute_dtype)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:579, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     572 if self.use_cudnn is True:
#     573     raise ValueError(
#     574         "use_cudnn=True was specified, "
#     575         "but cuDNN is not supported for this layer configuration "
#     576         "with this backend. Pass use_cudnn='auto' to fallback "
#     577         "to a non-cuDNN implementation."
#     578     )
# --> 579 return super().inner_loop(
#     580     sequences, initial_state, mask=mask, training=training
#     581 )
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:348, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     345 if not tree.is_nested(initial_state):
#     346     initial_state = [initial_state]
# --> 348 return backend.rnn(
#     349     step,
#     350     sequences,
#     351     initial_state,
#     352     go_backwards=self.go_backwards,
#     353     mask=mask,
#     354     unroll=self.unroll,
#     355     input_length=sequences.shape[1],
#     356     zero_output_for_mask=self.zero_output_for_mask,
#     357     return_all_outputs=self.return_sequences,
#     358 )
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\rnn.py:262, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     257 input_time_zero = tree.pack_sequence_as(
#     258     inputs, [inp[0] for inp in flattened_inputs]
#     259 )
#     260 # output_time_zero is used to determine the cell output shape and its
#     261 # dtype.  the value is discarded.
# --> 262 output_time_zero, _ = step_function(
#     263     input_time_zero, tuple(initial_states) + tuple(constants)
#     264 )
#     266 output_ta_size = time_steps_t if return_all_outputs else 1
#     267 output_ta = tuple(
#     268     tf.TensorArray(
#     269         dtype=out.dtype,
#    (...)    274     for i, out in enumerate(tree.flatten(output_time_zero))
#     275 )
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:340, in RNN.inner_loop.<locals>.step(inputs, states)
#     338 if backend.backend() == "torch" and self.stateful:
#     339     states = tree.map_structure(ops.copy, states)
# --> 340 output, new_states = self.cell(inputs, states, **cell_kwargs)
#     341 if not tree.is_nested(new_states):
#     342     new_states = [new_states]
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\layer.py:910, in Layer.__call__(self, *args, **kwargs)
#     908         outputs = super().__call__(*args, **kwargs)
#     909 else:
# --> 910     outputs = super().__call__(*args, **kwargs)
#     911 # Change the layout for the layer output if needed.
#     912 # This is useful for relayout intermediate tensor in the model
#     913 # to achieve the optimal performance.
#     914 distribution = distribution_lib.distribution()
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\ops\operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:285, in LSTMCell.call(self, inputs, states, training)
#     282         z += self.bias
#     284     z = ops.split(z, 4, axis=1)
# --> 285     c, o = self._compute_carry_and_output_fused(z, c_tm1)
#     287 h = o * self.activation(c)
#     288 return h, [h, c]
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:227, in LSTMCell._compute_carry_and_output_fused(self, z, c_tm1)
#     225 i = self.recurrent_activation(z0)
#     226 f = self.recurrent_activation(z1)
# --> 227 c = f * c_tm1 + i * self.activation(z2)
#     228 o = self.recurrent_activation(z3)
#     229 return c, o
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\override_binary_operator.py:113, in override_binary_operator_helper.<locals>.binary_op_wrapper(x, y)
#     108 try:
#     109   # force_same_dtype=False to preserve existing TF behavior
#     110   # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111   #   r_binary_op_wrapper use different force_same_dtype values.
#     112   x, y = maybe_promote_tensors(x, y)
# --> 113   return func(x, y, name=name)
#     114 except (TypeError, ValueError) as e:
#     115   # Even if dispatching the op failed, the RHS may be a tensor aware
#     116   # object that can implement the operator with knowledge of itself
#    (...)    119   # original error from the LHS, because it may be more
#     120   # informative.
#     121   if hasattr(type(y), "__r%s__" % op_name):
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py:76, in _mul_dispatch_factory(x, y, name)
#      65 if (isinstance(x, tensor_lib.Tensor) and x.dtype == dtypes.bool) or (
#      66     isinstance(y, tensor_lib.Tensor) and y.dtype == dtypes.bool
#      67 ):
#      68   return gen_math_ops.cast(
#      69       math_ops._mul_dispatch(
#      70           gen_math_ops.cast(x, dtypes.int32),
#    (...)     74       dtypes.bool,
#      75   )  # pylint: disable=protected-access
# ---> 76 return math_ops._mul_dispatch(x, y, name=name)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\ops\math_ops.py:1748, in _mul_dispatch(x, y, name)
#    1746   return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1747 else:
# -> 1748   return multiply(x, y, name=name)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\ops\math_ops.py:526, in multiply(x, y, name)
#     477 @tf_export("math.multiply", "multiply")
#     478 @dispatch.register_binary_elementwise_api
#     479 @dispatch.add_dispatch_support
#     480 def multiply(x, y, name=None):
#     481   """Returns an element-wise x * y.
#     482
#     483   For example:
#    (...)    523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
# --> 526   return gen_math_ops.mul(x, y, name)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6837, in mul(x, y, name)
#    6835     pass  # Add nodes to the TensorFlow graph.
#    6836 # Add nodes to the TensorFlow graph.
# -> 6837 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6838       "Mul", x=x, y=y, name=name)
#    6839 _result = _outputs[:]
#    6840 if _execute.must_record_gradient():
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:614, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     612   inp = self.capture(inp)
#     613   captured_inputs.append(inp)
# --> 614 return super()._create_op_internal(  # pylint: disable=protected-access
#     615     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     616     compute_device)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2705, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2702 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2703 # Session.run call cannot occur between creating and mutating the op.
#    2704 with self._mutation_lock():
# -> 2705   ret = Operation.from_node_def(
#    2706       node_def,
#    2707       self,
#    2708       inputs=inputs,
#    2709       output_types=dtypes,
#    2710       control_inputs=control_inputs,
#    2711       input_types=input_types,
#    2712       original_op=self._default_original_op,
#    2713       op_def=op_def,
#    2714   )
#    2715   self._create_op_helper(ret, compute_device=compute_device)
#    2716 return ret
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1200, in Operation.from_node_def(***failed resolving arguments***)
#    1197     control_input_ops.append(control_op)
#    1199 # Initialize c_op from node_def and other inputs
# -> 1200 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1201 self = Operation(c_op, SymbolicTensor)
#    1202 self._init(g)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ic2594\AppData\Local\miniconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1057, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1053   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1054                                          serialized)
#    1056 try:
# -> 1057   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1058 except errors.InvalidArgumentError as e:
#    1059   # Convert to ValueError for backwards compatibility.
#    1060   raise ValueError(e.message)
#
# KeyboardInterrupt:
